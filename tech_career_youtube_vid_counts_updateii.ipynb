# %%
# Dependencies & Setup
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt


# File to Load 
youtube_data_load = Path("video_data_cleaned.csv")

# Read the file & store into Pandas Dataframe
youtube_data = pd.read_csv(youtube_data_load)

# Print
youtube_data
# Out:
#        Unnamed: 0           id Channel Title          Published At  \
# 0               0  2ruoagytC7w    PushToProd  2023-09-14T21:00:02Z
# 1               1  gBH1LdSZyFU    PushToProd  2023-09-04T22:27:11Z
# 2               2  UhMJ0km4KLs    PushToProd  2023-08-15T21:30:03Z
# 3               3  qYfxI07QrKo    PushToProd  2023-06-13T20:45:01Z
# 4               4  CKcYF3369LI    PushToProd  2023-06-07T14:00:10Z
# ...           ...          ...           ...                   ...
# 26506       26506  LMyFZVkJsLQ    Chris Sean  2017-01-14T05:43:23Z
# 26507       26507  rG3HPCGB4hU    Chris Sean  2017-01-09T16:45:08Z
# 26508       26508  HLgdtA-n_bo    Chris Sean  2016-12-30T00:38:56Z
# 26509       26509  yAYJD4kKQ7c    Chris Sean  2016-12-22T17:12:12Z
# 26510       26510  6LzNLPwFwR0    Chris Sean  2016-12-12T06:13:25Z
#
#                      Channel Id  \
# 0      UCN0u98NPeC0AW3pD6MbVeNg
# 1      UCN0u98NPeC0AW3pD6MbVeNg
# 2      UCN0u98NPeC0AW3pD6MbVeNg
# 3      UCN0u98NPeC0AW3pD6MbVeNg
# 4      UCN0u98NPeC0AW3pD6MbVeNg
# ...                         ...
# 26506  UCu1xbgCV5o48h_BYCQD7KJg
# 26507  UCu1xbgCV5o48h_BYCQD7KJg
# 26508  UCu1xbgCV5o48h_BYCQD7KJg
# 26509  UCu1xbgCV5o48h_BYCQD7KJg
# 26510  UCu1xbgCV5o48h_BYCQD7KJg
#
#                                              Video Title  Category Id  \
# 0      day in the life | Jr. Cybersecurity Engineer N...           28
# 1      day in the life | Jr. Cybersecurity Engineer N...           28
# 2                  Prodcast 6 | Is the end of tech near?           28
# 3          Prodcast 5 | Biology Degree to Data Scientist           28
# 4      From Suit & Tie to Bonnets and Durags: Embraci...           28
# ...                                                  ...          ...
# 26506  All You NEED to BECOME A JUNIOR Web Developer ...           22
# 26507  At The Office, Bad Day & Knowing Your Value | ...           22
# 26508    What It Takes To Become A Web Developer in 2017           22
# 26509  Developers Q & A  | Be Humble But Stay Competi...           22
# 26510                 How Can You Become A Web Developer           22
#
#                                              Description  \
# 0      Here’s the part 2 to my day in the life/ vlog!...
# 1      Hey Guys! \n\nHope you enjoy Part 1 of this da...
# 2      https://linktr.ee/pushtoprod\n\nHey push2prod ...
# 3      Hey push2prod squad. Welcome to back to the "P...
# 4                                                    NaN
# ...                                                  ...
# 26506  Learn to CODE in just a FEW months here: \n- M...
# 26507  Learn to CODE in just a FEW months here: \n- M...
# 26508  Learn to CODE in just a FEW months here: \n- M...
# 26509  Q & A | Be Humble But Stay Competitive \n\nNot...
# 26510  How Can You Become a Web Developer?\n\nTreeHou...
#
#                                                     Tags  Duration  ...  \
# 0      ['devops', 'azure', 'aws', 'cloud', 'docker', ...   PT7M22S  ...
# 1      ['devops', 'azure', 'aws', 'cloud', 'docker', ...   PT14M8S  ...
# 2      ['podcast', 'devops', 'azure', 'aws', 'cloud',...  PT19M29S  ...
# 3      ['podcast', 'devops', 'azure', 'aws', 'cloud',...   PT25M9S  ...
# 4      ['podcast', 'devops', 'azure', 'aws', 'cloud',...     PT56S  ...
# ...                                                  ...       ...  ...
# 26506  ['how to become a jr web developer', 'junior w...      PT9M  ...
# 26507  ['daily life of a developer', 'the day in the ...    PT8M8S  ...
# 26508  ['Learn code', 'html', 'php', 'css', 'jquery',...   PT7M35S  ...
# 26509  ['developer q & a', 'how to become a developer...     PT14M  ...
# 26510  ['How can you become a developer?', 'How to be...   PT5M42S  ...
#
#       LicensedContent   Projection  View Count  Like Count Favorite Count  \
# 0                True  rectangular        1032        61.0              0
# 1                True  rectangular        2006        86.0              0
# 2                True  rectangular         793        55.0              0
# 3                True  rectangular         870        54.0              0
# 4                True  rectangular        1679        36.0              0
# ...               ...          ...         ...         ...            ...
# 26506            True  rectangular      192485      6246.0              0
# 26507            True  rectangular        6810       197.0              0
# 26508            True  rectangular        7054       247.0              0
# 26509            True  rectangular        3807       134.0              0
# 26510           False  rectangular        9819       337.0              0
#
#        Comment Count  Tag Count  Description Length (characters)  \
# 0               22.0       39.0                              162
# 1               29.0       39.0                              453
# 2               23.0       39.0                              456
# 3               22.0       38.0                              393
# 4                3.0       38.0                                0
# ...              ...        ...                              ...
# 26506          504.0       18.0                              336
# 26507           25.0       14.0                              336
# 26508           43.0       20.0                              336
# 26509           16.0       14.0                              385
# 26510           35.0       20.0                              744
#
#        Description Length (words)  Duration (seconds)
# 0                              20                 442
# 1                              72                 848
# 2                              75                1169
# 3                              70                1509
# 4                               1                  56
# ...                           ...                 ...
# 26506                          36                 540
# 26507                          36                 488
# 26508                          36                 455
# 26509                          38                 840
# 26510                          54                 342
#
# [26511 rows x 23 columns]

# %%
# Define the keywords to search for 2019
keyword1 = 'Software Developer'
keyword2 = '2019'

# Use str.contains on both columns
result_sd_nineteen = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 20219
keyword1 = 'Data Scientist'
keyword2 = '2019'

# Use str.contains on both columns
result_ds_nineteen = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2019
keyword1 = 'Data Analysis'
keyword2 = '2019'

# Use str.contains on both columns
result_da_nineteen = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2019 
keyword1 = 'Web Developer'
keyword2 = '2019'

# Use str.contains on both columns
result_wd_nineteen = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2019
keyword1 = 'Business Analyst'
keyword2 = '2019'

# Use str.contains on both columns
result_ba_nineteen = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# create a df summary for 2019
twenty_nineteen_summary = ({
    "Software Developer" : [result_sd_nineteen],
    "Data Scientist": [result_ds_nineteen],
    "Data Analysis" : [result_da_nineteen],
    "Business Analyst" : [result_ba_nineteen],
    "Web Developer" : [result_wd_nineteen]
    
})

twenty_nineteen_summary
# Out:
# {'Software Developer': [Unnamed: 0                         1712
#   id                                 1712
#   Channel Title                      1712
#   Published At                       1712
#   Channel Id                         1712
#   Video Title                        1712
#   Category Id                        1712
#   Description                        1709
#   Tags                               1712
#   Duration                           1712
#   Dimension                          1712
#   Definition                         1712
#   Caption                            1712
#   LicensedContent                    1712
#   Projection                         1712
#   View Count                         1712
#   Like Count                         1694
#   Favorite Count                     1712
#   Comment Count                      1711
#   Tag Count                          1712
#   Description Length (characters)    1712
#   Description Length (words)         1712
#   Duration (seconds)                 1712
#   dtype: int64],
#  'Data Scientist': [Unnamed: 0                         1671
#   id                                 1671
#   Channel Title                      1671
#   Published At                       1671
#   Channel Id                         1671
#   Video Title                        1671
#   Category Id                        1671
#   Description                        1669
#   Tags                               1671
#   Duration                           1671
#   Dimension                          1671
#   Definition                         1671
#   Caption                            1671
#   LicensedContent                    1671
#   Projection                         1671
#   View Count                         1671
#   Like Count                         1652
#   Favorite Count                     1671
#   Comment Count                      1670
#   Tag Count                          1671
#   Description Length (characters)    1671
#   Description Length (words)         1671
#   Duration (seconds)                 1671
#   dtype: int64],
#  'Data Analysis': [Unnamed: 0                         1645
#   id                                 1645
#   Channel Title                      1645
#   Published At                       1645
#   Channel Id                         1645
#   Video Title                        1645
#   Category Id                        1645
#   Description                        1644
#   Tags                               1645
#   Duration                           1645
#   Dimension                          1645
#   Definition                         1645
#   Caption                            1645
#   LicensedContent                    1645
#   Projection                         1645
#   View Count                         1645
#   Like Count                         1626
#   Favorite Count                     1645
#   Comment Count                      1644
#   Tag Count                          1645
#   Description Length (characters)    1645
#   Description Length (words)         1645
#   Duration (seconds)                 1645
#   dtype: int64],
#  'Business Analyst': [Unnamed: 0                         1618
#   id                                 1618
#   Channel Title                      1618
#   Published At                       1618
#   Channel Id                         1618
#   Video Title                        1618
#   Category Id                        1618
#   Description                        1617
#   Tags                               1618
#   Duration                           1618
#   Dimension                          1618
#   Definition                         1618
#   Caption                            1618
#   LicensedContent                    1618
#   Projection                         1618
#   View Count                         1618
#   Like Count                         1600
#   Favorite Count                     1618
#   Comment Count                      1617
#   Tag Count                          1618
#   Description Length (characters)    1618
#   Description Length (words)         1618
#   Duration (seconds)                 1618
#   dtype: int64],
#  'Web Developer': [Unnamed: 0                         1759
#   id                                 1759
#   Channel Title                      1759
#   Published At                       1759
#   Channel Id                         1759
#   Video Title                        1759
#   Category Id                        1759
#   Description                        1757
#   Tags                               1759
#   Duration                           1759
#   Dimension                          1759
#   Definition                         1759
#   Caption                            1759
#   LicensedContent                    1759
#   Projection                         1759
#   View Count                         1759
#   Like Count                         1741
#   Favorite Count                     1759
#   Comment Count                      1757
#   Tag Count                          1759
#   Description Length (characters)    1759
#   Description Length (words)         1759
#   Duration (seconds)                 1759
#   dtype: int64]}

# %%
#graph 2019 for video titles
# plot a bar chart for the Tags columns 
tech_careers = ["Software Developer",
    "Data Scientist",
    "Data Analysis",
    "Business Analyst",
    "Web Developer"]
youtube_video_count = ["1712",
                      "1671",
                       "1645",
                       "1618",
                       "1759",]


colors = ["purple", 
          "orange", 
          "lightcoral", 
          "lightskyblue", 
          "lightgreen",]

plt.title("Top Tech Youtube Videos in 2019")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")

# Set the y-axis limits to zoom in
plt.ylim(1500, 1800)  

plt.bar(tech_careers, [int(count) for count in youtube_video_count], color=colors,align="center")

# Rotate the x axis labels for better view 
plt.xticks(rotation=90)

# Save total count tagged chart 

plt.show()

# %%
# Define the keywords to search for 2020 
keyword1 = 'Software Developer'
keyword2 = '2020'

# Use str.contains on both columns
result_sd = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2020 
keyword1 = 'Data Scientist'
keyword2 = '2020'

# Use str.contains on both columns
result_ds = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2020 
keyword1 = 'Data Analysis'
keyword2 = '2020'

# Use str.contains on both columns
result_da = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2020 
keyword1 = 'Web Developer'
keyword2 = '2020'

# Use str.contains on both columns
result_wd = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2020 
keyword1 = 'Business Analyst'
keyword2 = '2020'

# Use str.contains on both columns
result_ba = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# create a df summary for 2020
twenty_twenty_summary = ({
    "Software Developer" : [result_sd],
    "Data Scientist": [result_ds],
    "Data Analysis" : [result_da],
    "Business Analyst" : [result_ba],
    "Web Developer" : [result_wd]
    
})

twenty_twenty_summary
# Out:
# {'Software Developer': [Unnamed: 0                         2640
#   id                                 2640
#   Channel Title                      2640
#   Published At                       2640
#   Channel Id                         2640
#   Video Title                        2640
#   Category Id                        2640
#   Description                        2634
#   Tags                               2640
#   Duration                           2640
#   Dimension                          2640
#   Definition                         2640
#   Caption                            2640
#   LicensedContent                    2640
#   Projection                         2640
#   View Count                         2640
#   Like Count                         2595
#   Favorite Count                     2640
#   Comment Count                      2632
#   Tag Count                          2640
#   Description Length (characters)    2640
#   Description Length (words)         2640
#   Duration (seconds)                 2640
#   dtype: int64],
#  'Data Scientist': [Unnamed: 0                         2603
#   id                                 2603
#   Channel Title                      2603
#   Published At                       2603
#   Channel Id                         2603
#   Video Title                        2603
#   Category Id                        2603
#   Description                        2598
#   Tags                               2603
#   Duration                           2603
#   Dimension                          2603
#   Definition                         2603
#   Caption                            2603
#   LicensedContent                    2603
#   Projection                         2603
#   View Count                         2603
#   Like Count                         2557
#   Favorite Count                     2603
#   Comment Count                      2595
#   Tag Count                          2603
#   Description Length (characters)    2603
#   Description Length (words)         2603
#   Duration (seconds)                 2603
#   dtype: int64],
#  'Data Analysis': [Unnamed: 0                         2566
#   id                                 2566
#   Channel Title                      2566
#   Published At                       2566
#   Channel Id                         2566
#   Video Title                        2566
#   Category Id                        2566
#   Description                        2562
#   Tags                               2566
#   Duration                           2566
#   Dimension                          2566
#   Definition                         2566
#   Caption                            2566
#   LicensedContent                    2566
#   Projection                         2566
#   View Count                         2566
#   Like Count                         2520
#   Favorite Count                     2566
#   Comment Count                      2558
#   Tag Count                          2566
#   Description Length (characters)    2566
#   Description Length (words)         2566
#   Duration (seconds)                 2566
#   dtype: int64],
#  'Business Analyst': [Unnamed: 0                         2552
#   id                                 2552
#   Channel Title                      2552
#   Published At                       2552
#   Channel Id                         2552
#   Video Title                        2552
#   Category Id                        2552
#   Description                        2548
#   Tags                               2552
#   Duration                           2552
#   Dimension                          2552
#   Definition                         2552
#   Caption                            2552
#   LicensedContent                    2552
#   Projection                         2552
#   View Count                         2552
#   Like Count                         2507
#   Favorite Count                     2552
#   Comment Count                      2544
#   Tag Count                          2552
#   Description Length (characters)    2552
#   Description Length (words)         2552
#   Duration (seconds)                 2552
#   dtype: int64],
#  'Web Developer': [Unnamed: 0                         2676
#   id                                 2676
#   Channel Title                      2676
#   Published At                       2676
#   Channel Id                         2676
#   Video Title                        2676
#   Category Id                        2676
#   Description                        2671
#   Tags                               2676
#   Duration                           2676
#   Dimension                          2676
#   Definition                         2676
#   Caption                            2676
#   LicensedContent                    2676
#   Projection                         2676
#   View Count                         2676
#   Like Count                         2631
#   Favorite Count                     2676
#   Comment Count                      2668
#   Tag Count                          2676
#   Description Length (characters)    2676
#   Description Length (words)         2676
#   Duration (seconds)                 2676
#   dtype: int64]}

# %%
#graph 2020 for video titles
# plot a bar chart for the Tags columns 
tech_careers = ["Software Developer",
    "Data Scientist",
    "Data Analysis",
    "Business Analyst",
    "Web Developer"]
youtube_video_count = ["2640",
                      "2603",
                       "2566",
                       "2552",
                       "2676",]


colors = ["purple", 
          "orange", 
          "lightcoral", 
          "lightskyblue", 
          "lightgreen",]

plt.title("Top Tech Youtube Videos in 2020 & 2021 ")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")

# Set the y-axis limits to zoom in
plt.ylim(2500, 2700)  

plt.bar(tech_careers, [int(count) for count in youtube_video_count], color=colors,align="center")

# Rotate the x axis labels for better view 
plt.xticks(rotation=90)

# Save total count tagged chart 
plt.tight.layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 33
#      30 plt.xticks(rotation=90)
#      32 # Save total count tagged chart
# ---> 33 plt.tight.layout()
#      34 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tight'

# %%
# data for 2021

# %%
# Define the keywords to search for 2021
keyword1 = 'Software Developer'
keyword2 = '2021'

# Use str.contains on both columns
result_sd_one = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2021 
keyword1 = 'Data Scientist'
keyword2 = '2021'

# Use str.contains on both columns
result_ds_one = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2021 
keyword1 = 'Data Analysis'
keyword2 = '2021'

# Use str.contains on both columns
result_da_one = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2021
keyword1 = 'Web Developer'
keyword2 = '2021'

# Use str.contains on both columns
result_wd_one= youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2021
keyword1 = 'Business Analyst'
keyword2 = '2021'

# Use str.contains on both columns
result_ba_one = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# create a df summary for 2021
twenty_one_summary = ({
    "Software Developer" : [result_sd_one],
    "Data Scientist": [result_ds_one],
    "Data Analysis" : [result_da_one],
    "Business Analyst" : [result_ba_one],
    "Web Developer" : [result_wd_one]
    
})

twenty_one_summary
# Out:
# {'Software Developer': [Unnamed: 0                         4188
#   id                                 4188
#   Channel Title                      4188
#   Published At                       4188
#   Channel Id                         4188
#   Video Title                        4188
#   Category Id                        4188
#   Description                        4073
#   Tags                               4188
#   Duration                           4188
#   Dimension                          4188
#   Definition                         4188
#   Caption                            4188
#   LicensedContent                    4188
#   Projection                         4188
#   View Count                         4188
#   Like Count                         4155
#   Favorite Count                     4188
#   Comment Count                      4175
#   Tag Count                          4188
#   Description Length (characters)    4188
#   Description Length (words)         4188
#   Duration (seconds)                 4188
#   dtype: int64],
#  'Data Scientist': [Unnamed: 0                         4181
#   id                                 4181
#   Channel Title                      4181
#   Published At                       4181
#   Channel Id                         4181
#   Video Title                        4181
#   Category Id                        4181
#   Description                        4067
#   Tags                               4181
#   Duration                           4181
#   Dimension                          4181
#   Definition                         4181
#   Caption                            4181
#   LicensedContent                    4181
#   Projection                         4181
#   View Count                         4181
#   Like Count                         4147
#   Favorite Count                     4181
#   Comment Count                      4168
#   Tag Count                          4181
#   Description Length (characters)    4181
#   Description Length (words)         4181
#   Duration (seconds)                 4181
#   dtype: int64],
#  'Data Analysis': [Unnamed: 0                         4143
#   id                                 4143
#   Channel Title                      4143
#   Published At                       4143
#   Channel Id                         4143
#   Video Title                        4143
#   Category Id                        4143
#   Description                        4030
#   Tags                               4143
#   Duration                           4143
#   Dimension                          4143
#   Definition                         4143
#   Caption                            4143
#   LicensedContent                    4143
#   Projection                         4143
#   View Count                         4143
#   Like Count                         4109
#   Favorite Count                     4143
#   Comment Count                      4130
#   Tag Count                          4143
#   Description Length (characters)    4143
#   Description Length (words)         4143
#   Duration (seconds)                 4143
#   dtype: int64],
#  'Business Analyst': [Unnamed: 0                         4130
#   id                                 4130
#   Channel Title                      4130
#   Published At                       4130
#   Channel Id                         4130
#   Video Title                        4130
#   Category Id                        4130
#   Description                        4017
#   Tags                               4130
#   Duration                           4130
#   Dimension                          4130
#   Definition                         4130
#   Caption                            4130
#   LicensedContent                    4130
#   Projection                         4130
#   View Count                         4130
#   Like Count                         4097
#   Favorite Count                     4130
#   Comment Count                      4117
#   Tag Count                          4130
#   Description Length (characters)    4130
#   Description Length (words)         4130
#   Duration (seconds)                 4130
#   dtype: int64],
#  'Web Developer': [Unnamed: 0                         4280
#   id                                 4280
#   Channel Title                      4280
#   Published At                       4280
#   Channel Id                         4280
#   Video Title                        4280
#   Category Id                        4280
#   Description                        4166
#   Tags                               4280
#   Duration                           4280
#   Dimension                          4280
#   Definition                         4280
#   Caption                            4280
#   LicensedContent                    4280
#   Projection                         4280
#   View Count                         4280
#   Like Count                         4247
#   Favorite Count                     4280
#   Comment Count                      4266
#   Tag Count                          4280
#   Description Length (characters)    4280
#   Description Length (words)         4280
#   Duration (seconds)                 4280
#   dtype: int64]}

# %%
#graph 2021 for video titles
# plot a bar chart for the Tags columns 
tech_careers = ["Software Developer",
    "Data Scientist",
    "Data Analysis",
    "Business Analyst",
    "Web Developer"]
youtube_video_count = ["4188",
                      "4181",
                       "4143",
                       "4130",
                       "4280",]

colors = ["purple", 
          "orange", 
          "lightcoral", 
          "lightskyblue", 
          "lightgreen",]

plt.title("Top Tech Youtube Videos 2021")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")

# Set the y-axis limits to zoom in
plt.ylim(4100, 4300)  

plt.bar(tech_careers, [int(count) for count in youtube_video_count], color=colors,align="center")

# Rotate the x axis labels for better view 
plt.xticks(rotation=90)

# Save total count tagged chart 
plt.tight.layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 33
#      30 plt.xticks(rotation=90)
#      32 # Save total count tagged chart
# ---> 33 plt.tight.layout()
#      34 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tight'

# %%
# data for 2022

# %%
# Define the keywords to search for 2022
keyword1 = 'Software Developer'
keyword2 = '2022'

# Use str.contains on both columns
result_sd_two = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2022 
keyword1 = 'Data Scientist'
keyword2 = '2022'

# Use str.contains on both columns
result_ds_two = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2022
keyword1 = 'Data Analysis'
keyword2 = '2022'

# Use str.contains on both columns
result_da_two = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2022
keyword1 = 'Web Developer'
keyword2 = '2022'

# Use str.contains on both columns
result_wd_two= youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2022
keyword1 = 'Business Analyst'
keyword2 = '2022'

# Use str.contains on both columns
result_ba_two = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# create a df summary for 2022
twenty_two_summary = ({
    "Software Developer" : [result_sd_two],
    "Data Scientist": [result_ds_two],
    "Data Analysis" : [result_da_two],
    "Business Analyst" : [result_ba_two],
    "Web Developer" : [result_wd_two]
    
})

twenty_two_summary
# Out:
# {'Software Developer': [Unnamed: 0                         6258
#   id                                 6258
#   Channel Title                      6258
#   Published At                       6258
#   Channel Id                         6258
#   Video Title                        6258
#   Category Id                        6258
#   Description                        5683
#   Tags                               6258
#   Duration                           6258
#   Dimension                          6258
#   Definition                         6258
#   Caption                            6258
#   LicensedContent                    6258
#   Projection                         6258
#   View Count                         6258
#   Like Count                         6232
#   Favorite Count                     6258
#   Comment Count                      6246
#   Tag Count                          6258
#   Description Length (characters)    6258
#   Description Length (words)         6258
#   Duration (seconds)                 6258
#   dtype: int64],
#  'Data Scientist': [Unnamed: 0                         6234
#   id                                 6234
#   Channel Title                      6234
#   Published At                       6234
#   Channel Id                         6234
#   Video Title                        6234
#   Category Id                        6234
#   Description                        5659
#   Tags                               6234
#   Duration                           6234
#   Dimension                          6234
#   Definition                         6234
#   Caption                            6234
#   LicensedContent                    6234
#   Projection                         6234
#   View Count                         6234
#   Like Count                         6208
#   Favorite Count                     6234
#   Comment Count                      6222
#   Tag Count                          6234
#   Description Length (characters)    6234
#   Description Length (words)         6234
#   Duration (seconds)                 6234
#   dtype: int64],
#  'Data Analysis': [Unnamed: 0                         6212
#   id                                 6212
#   Channel Title                      6212
#   Published At                       6212
#   Channel Id                         6212
#   Video Title                        6212
#   Category Id                        6212
#   Description                        5637
#   Tags                               6212
#   Duration                           6212
#   Dimension                          6212
#   Definition                         6212
#   Caption                            6212
#   LicensedContent                    6212
#   Projection                         6212
#   View Count                         6212
#   Like Count                         6185
#   Favorite Count                     6212
#   Comment Count                      6200
#   Tag Count                          6212
#   Description Length (characters)    6212
#   Description Length (words)         6212
#   Duration (seconds)                 6212
#   dtype: int64],
#  'Business Analyst': [Unnamed: 0                         6200
#   id                                 6200
#   Channel Title                      6200
#   Published At                       6200
#   Channel Id                         6200
#   Video Title                        6200
#   Category Id                        6200
#   Description                        5625
#   Tags                               6200
#   Duration                           6200
#   Dimension                          6200
#   Definition                         6200
#   Caption                            6200
#   LicensedContent                    6200
#   Projection                         6200
#   View Count                         6200
#   Like Count                         6174
#   Favorite Count                     6200
#   Comment Count                      6188
#   Tag Count                          6200
#   Description Length (characters)    6200
#   Description Length (words)         6200
#   Duration (seconds)                 6200
#   dtype: int64],
#  'Web Developer': [Unnamed: 0                         6345
#   id                                 6345
#   Channel Title                      6345
#   Published At                       6345
#   Channel Id                         6345
#   Video Title                        6345
#   Category Id                        6345
#   Description                        5771
#   Tags                               6345
#   Duration                           6345
#   Dimension                          6345
#   Definition                         6345
#   Caption                            6345
#   LicensedContent                    6345
#   Projection                         6345
#   View Count                         6345
#   Like Count                         6319
#   Favorite Count                     6345
#   Comment Count                      6332
#   Tag Count                          6345
#   Description Length (characters)    6345
#   Description Length (words)         6345
#   Duration (seconds)                 6345
#   dtype: int64]}

# %%
#graph 2022 for video titles
# plot a bar chart for the Tags columns 
tech_careers = ["Software Developer",
    "Data Scientist",
    "Data Analysis",
    "Business Analyst",
    "Web Developer"]
youtube_video_count = ["6258",
                      "6234",
                       "6212",
                       "6200",
                       "6345",]

colors = ["purple", 
          "orange", 
          "lightcoral", 
          "lightskyblue", 
          "lightgreen",]

plt.title("Top Tech Youtube Videos 2022 ")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")

# Set the y-axis limits to zoom in
plt.ylim(6100, 6400)  

plt.bar(tech_careers, [int(count) for count in youtube_video_count], color=colors,align="center")

# Rotate the x axis labels for better view 
plt.xticks(rotation=90)

# Save total count tagged chart 
plt.tight.layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 33
#      30 plt.xticks(rotation=90)
#      32 # Save total count tagged chart
# ---> 33 plt.tight.layout()
#      34 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tight'

# %%
# data for 2023

# %%
# Define the keywords to search for 2023
keyword1 = 'Software Developer'
keyword2 = '2023'

# Use str.contains on both columns
result_sd_three = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2023 
keyword1 = 'Data Scientist'
keyword2 = '2023'

# Use str.contains on both columns
result_ds_three = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2023
keyword1 = 'Data Analysis'
keyword2 = '2023'

# Use str.contains on both columns
result_da_three = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2023
keyword1 = 'Web Developer'
keyword2 = '2023'

# Use str.contains on both columns
result_wd_three= youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# Define the keywords to search for 2023
keyword1 = 'Business Analyst'
keyword2 = '2023'

# Use str.contains on both columns
result_ba_three = youtube_data[youtube_data['Video Title'].str.contains(keyword1, case=True) | youtube_data['Published At'].str.contains(keyword2, case=True)].count()

# %%
# create a df summary for 2023
twenty_three_summary = ({
    "Software Developer" : [result_sd_three],
    "Data Scientist": [result_ds_three],
    "Data Analysis" : [result_da_three],
    "Business Analyst" : [result_ba_three],
    "Web Developer" : [result_wd_three]
    
})

twenty_three_summary
# Out:
# {'Software Developer': [Unnamed: 0                         6601
#   id                                 6601
#   Channel Title                      6601
#   Published At                       6601
#   Channel Id                         6601
#   Video Title                        6601
#   Category Id                        6601
#   Description                        5944
#   Tags                               6601
#   Duration                           6601
#   Dimension                          6601
#   Definition                         6601
#   Caption                            6601
#   LicensedContent                    6601
#   Projection                         6601
#   View Count                         6601
#   Like Count                         6575
#   Favorite Count                     6601
#   Comment Count                      6588
#   Tag Count                          6601
#   Description Length (characters)    6601
#   Description Length (words)         6601
#   Duration (seconds)                 6601
#   dtype: int64],
#  'Data Scientist': [Unnamed: 0                         6552
#   id                                 6552
#   Channel Title                      6552
#   Published At                       6552
#   Channel Id                         6552
#   Video Title                        6552
#   Category Id                        6552
#   Description                        5896
#   Tags                               6552
#   Duration                           6552
#   Dimension                          6552
#   Definition                         6552
#   Caption                            6552
#   LicensedContent                    6552
#   Projection                         6552
#   View Count                         6552
#   Like Count                         6525
#   Favorite Count                     6552
#   Comment Count                      6539
#   Tag Count                          6552
#   Description Length (characters)    6552
#   Description Length (words)         6552
#   Duration (seconds)                 6552
#   dtype: int64],
#  'Data Analysis': [Unnamed: 0                         6555
#   id                                 6555
#   Channel Title                      6555
#   Published At                       6555
#   Channel Id                         6555
#   Video Title                        6555
#   Category Id                        6555
#   Description                        5900
#   Tags                               6555
#   Duration                           6555
#   Dimension                          6555
#   Definition                         6555
#   Caption                            6555
#   LicensedContent                    6555
#   Projection                         6555
#   View Count                         6555
#   Like Count                         6529
#   Favorite Count                     6555
#   Comment Count                      6542
#   Tag Count                          6555
#   Description Length (characters)    6555
#   Description Length (words)         6555
#   Duration (seconds)                 6555
#   dtype: int64],
#  'Business Analyst': [Unnamed: 0                         6508
#   id                                 6508
#   Channel Title                      6508
#   Published At                       6508
#   Channel Id                         6508
#   Video Title                        6508
#   Category Id                        6508
#   Description                        5853
#   Tags                               6508
#   Duration                           6508
#   Dimension                          6508
#   Definition                         6508
#   Caption                            6508
#   LicensedContent                    6508
#   Projection                         6508
#   View Count                         6508
#   Like Count                         6482
#   Favorite Count                     6508
#   Comment Count                      6495
#   Tag Count                          6508
#   Description Length (characters)    6508
#   Description Length (words)         6508
#   Duration (seconds)                 6508
#   dtype: int64],
#  'Web Developer': [Unnamed: 0                         6696
#   id                                 6696
#   Channel Title                      6696
#   Published At                       6696
#   Channel Id                         6696
#   Video Title                        6696
#   Category Id                        6696
#   Description                        6039
#   Tags                               6696
#   Duration                           6696
#   Dimension                          6696
#   Definition                         6696
#   Caption                            6696
#   LicensedContent                    6696
#   Projection                         6696
#   View Count                         6696
#   Like Count                         6670
#   Favorite Count                     6696
#   Comment Count                      6682
#   Tag Count                          6696
#   Description Length (characters)    6696
#   Description Length (words)         6696
#   Duration (seconds)                 6696
#   dtype: int64]}

# %%
#graph 2023 for video titles
# plot a bar chart for the Tags columns 
tech_careers = ["Software Developer",
    "Data Scientist",
    "Data Analysis",
    "Business Analyst",
    "Web Developer"]
youtube_video_count = ["6601",
                      "6552",
                       "6555",
                       "6508",
                       "6696",]

colors = ["purple", 
          "orange", 
          "lightcoral", 
          "lightskyblue", 
          "lightgreen",]

plt.title("Top Tech Youtube Videos 2023 ")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")

# Set the y-axis limits to zoom in
plt.ylim(6500, 6700)  

plt.bar(tech_careers, [int(count) for count in youtube_video_count], color=colors,align="center")

# Rotate the x axis labels for better view 
plt.xticks(rotation=90)

# Save total count tagged chart 
plt.tight.layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 33
#      30 plt.xticks(rotation=90)
#      32 # Save total count tagged chart
# ---> 33 plt.tight.layout()
#      34 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tight'

# %%
fig, ax = plt.subplots()
twenty_nineteen = ax.bar(index, ["Software Developer",
    "Data Scientist",
    "Data Analysis",
    "Business Analyst",
    "Web Developer"], bar_width,
                label="2019")

twenty_two = ax.bar(index+bar_width, df["Crime Type Winter"].value_counts(),
                 bar_width, label="Winter")

# %%
tech_careers = ["Software Developer", "Data Scientist", "Data Analysis", "Business Analyst", "Web Developer"]
youtube_video_count_2019 = [1712, 1671, 1645, 1618, 1759]
youtube_video_count_2020 = [2640, 2603, 2566, 2552, 2676]

bar_width = 0.35
index = np.arange(len(tech_careers))

plt.figure(figsize=(12, 6))

plt.bar(index - bar_width/2, youtube_video_count_2019, bar_width, label='2019', color='lightblue')
plt.bar(index + bar_width/2, youtube_video_count_2020, bar_width, label='2020', color='lightcoral')

plt.title("Tech YouTube Videos in 2019 and 2020")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")
plt.xticks(index, tech_careers, rotation=45)
plt.ylim(1500, 2900)
plt.legend()

plt.tight_layout()
plt.show()

# %%
tech_careers = ["Software Developer", "Data Scientist", "Data Analysis", "Business Analyst", "Web Developer"]
youtube_video_count_2021 = [4188, 4181, 4143, 4130, 4280]
youtube_video_count_2022 = [6258, 6234, 6212, 6200, 6345]

bar_width = 0.4
index = np.arange(len(tech_careers))

plt.figure(figsize=(12, 6))

plt.bar(index - bar_width/2, youtube_video_count_2021, bar_width, label='2021', color='lightblue')
plt.bar(index + bar_width/2, youtube_video_count_2022, bar_width, label='2022', color='lightcoral')

plt.title("Tech YouTube Videos (2021-2022)")
plt.xlabel("Tech Careers")
plt.ylabel("Total Videos")
plt.xticks(index, tech_careers, rotation=45)
plt.ylim(4000, 6500)
plt.legend()

plt.tight_layout()
plt.show()
